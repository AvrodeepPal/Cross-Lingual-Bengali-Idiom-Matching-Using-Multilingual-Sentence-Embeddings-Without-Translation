# %% [markdown]
# <a href="https://colab.research.google.com/github/Codebrokerrose/Cross-Lingual-Bengali-Idiom-Matching-Using-Multilingual-Sentence-Embeddings-Without-Translation/blob/main/notebooks/Cross-Lingual-Bengali-Idiom-Matching1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Colab is making it easier than ever to integrate powerful Generative AI capabilities into your projects. We are launching public preview for a simple and intuitive Python library (google.colab.ai) to access state-of-the-art language models directly within Colab environments. All users have free access to most popular LLMs, while paid users have access to a wider selection of models. This means users can spend less time on configuration and set up and more time bringing their ideas to life. With just a few lines of code, you can now perform a variety of tasks:
# - Generate text
# - Translate languages
# - Write creative content
# - Categorize text
#
# Happy Coding!
#
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/googlecolab/colabtools/blob/main/notebooks/Getting_started_with_google_colab_ai.ipynb)

# %%
# !git clone https://github.com/Codebrokerrose/Cross-Lingual-Bengali-Idiom-Matching-Using-Multilingual-Sentence-Embeddings-Without-Translation.git
# Out:
# Cloning into 'Cross-Lingual-Bengali-Idiom-Matching-Using-Multilingual-Sentence-Embeddings-Without-Translation'...
# remote: Enumerating objects: 10525, done.
# remote: Counting objects: 100% (10/10), done.
# remote: Compressing objects: 100% (10/10), done.
# remote: Total 10525 (delta 0), reused 3 (delta 0), pack-reused 10515 (from 2)
# Receiving objects: 100% (10525/10525), 149.56 MiB | 25.70 MiB/s, done.
# Resolving deltas: 100% (14/14), done.
# Updating files: 100% (10475/10475), done.

# %%
# %cd /content/Cross-Lingual-Bengali-Idiom-Matching-Using-Multilingual-Sentence-Embeddings-Without-Translation
# !pwd
# Out:
# /content/Cross-Lingual-Bengali-Idiom-Matching-Using-Multilingual-Sentence-Embeddings-Without-Translation
# /content/Cross-Lingual-Bengali-Idiom-Matching-Using-Multilingual-Sentence-Embeddings-Without-Translation

# %%
# !ls
# Out:
# data  README.md  requirements.txt  results  src

# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: sentence-transformers>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 1)) (5.4.1)
# Requirement already satisfied: transformers>=4.30.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 2)) (5.0.0)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 3)) (2.10.0+cpu)
# Requirement already satisfied: pandas>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 4)) (2.2.2)
# Requirement already satisfied: numpy>=1.23.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 5)) (2.0.2)
# Requirement already satisfied: scikit-learn>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 6)) (1.6.1)
# Requirement already satisfied: scipy>=1.10.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 7)) (1.16.3)
# Requirement already satisfied: matplotlib>=3.6.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 8)) (3.10.0)
# Requirement already satisfied: seaborn>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 9)) (0.13.2)
# Requirement already satisfied: datasets>=2.10.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 10)) (4.0.0)
# Requirement already satisfied: tqdm>=4.65.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 11)) (4.67.3)
# Requirement already satisfied: openpyxl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 12)) (3.1.5)
# Collecting langdetect>=1.0.9 (from -r requirements.txt (line 13))
#   Downloading langdetect-1.0.9.tar.gz (981 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 20.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting jupyter>=1.0.0 (from -r requirements.txt (line 14))
#   Downloading jupyter-1.1.1-py2.py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: ipykernel>=6.0.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 15)) (6.17.1)
# Requirement already satisfied: huggingface-hub>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from sentence-transformers>=2.2.0->-r requirements.txt (line 1)) (1.11.0)
# Requirement already satisfied: typing_extensions>=4.5.0 in /usr/local/lib/python3.12/dist-packages (from sentence-transformers>=2.2.0->-r requirements.txt (line 1)) (4.15.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers>=4.30.0->-r requirements.txt (line 2)) (3.29.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.30.0->-r requirements.txt (line 2)) (26.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.30.0->-r requirements.txt (line 2)) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.30.0->-r requirements.txt (line 2)) (2025.11.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.30.0->-r requirements.txt (line 2)) (0.22.2)
# Requirement already satisfied: typer-slim in /usr/local/lib/python3.12/dist-packages (from transformers>=4.30.0->-r requirements.txt (line 2)) (0.24.0)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.30.0->-r requirements.txt (line 2)) (0.7.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r requirements.txt (line 3)) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r requirements.txt (line 3)) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r requirements.txt (line 3)) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r requirements.txt (line 3)) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r requirements.txt (line 3)) (2025.3.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.5.0->-r requirements.txt (line 4)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.5.0->-r requirements.txt (line 4)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.5.0->-r requirements.txt (line 4)) (2026.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.2.0->-r requirements.txt (line 6)) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.2.0->-r requirements.txt (line 6)) (3.6.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.6.0->-r requirements.txt (line 8)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.6.0->-r requirements.txt (line 8)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.6.0->-r requirements.txt (line 8)) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.6.0->-r requirements.txt (line 8)) (1.5.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.6.0->-r requirements.txt (line 8)) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.6.0->-r requirements.txt (line 8)) (3.3.2)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets>=2.10.0->-r requirements.txt (line 10)) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from datasets>=2.10.0->-r requirements.txt (line 10)) (0.3.8)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.12/dist-packages (from datasets>=2.10.0->-r requirements.txt (line 10)) (2.32.4)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets>=2.10.0->-r requirements.txt (line 10)) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.12/dist-packages (from datasets>=2.10.0->-r requirements.txt (line 10)) (0.70.16)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.12/dist-packages (from openpyxl>=3.1.0->-r requirements.txt (line 12)) (2.0.0)
# Requirement already satisfied: six in /usr/local/lib/python3.12/dist-packages (from langdetect>=1.0.9->-r requirements.txt (line 13)) (1.17.0)
# Requirement already satisfied: notebook in /usr/local/lib/python3.12/dist-packages (from jupyter>=1.0.0->-r requirements.txt (line 14)) (6.5.7)
# Requirement already satisfied: jupyter-console in /usr/local/lib/python3.12/dist-packages (from jupyter>=1.0.0->-r requirements.txt (line 14)) (6.6.3)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.12/dist-packages (from jupyter>=1.0.0->-r requirements.txt (line 14)) (7.17.1)
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.12/dist-packages (from jupyter>=1.0.0->-r requirements.txt (line 14)) (7.7.1)
# Collecting jupyterlab (from jupyter>=1.0.0->-r requirements.txt (line 14))
#   Downloading jupyterlab-4.5.7-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: debugpy>=1.0 in /usr/local/lib/python3.12/dist-packages (from ipykernel>=6.0.0->-r requirements.txt (line 15)) (1.8.15)
# Requirement already satisfied: ipython>=7.23.1 in /usr/local/lib/python3.12/dist-packages (from ipykernel>=6.0.0->-r requirements.txt (line 15)) (7.34.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /usr/local/lib/python3.12/dist-packages (from ipykernel>=6.0.0->-r requirements.txt (line 15)) (7.4.9)
# Requirement already satisfied: matplotlib-inline>=0.1 in /usr/local/lib/python3.12/dist-packages (from ipykernel>=6.0.0->-r requirements.txt (line 15)) (0.2.1)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.12/dist-packages (from ipykernel>=6.0.0->-r requirements.txt (line 15)) (1.6.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from ipykernel>=6.0.0->-r requirements.txt (line 15)) (5.9.5)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.12/dist-packages (from ipykernel>=6.0.0->-r requirements.txt (line 15)) (26.2.1)
# Requirement already satisfied: tornado>=6.1 in /usr/local/lib/python3.12/dist-packages (from ipykernel>=6.0.0->-r requirements.txt (line 15)) (6.5.1)
# Requirement already satisfied: traitlets>=5.1.0 in /usr/local/lib/python3.12/dist-packages (from ipykernel>=6.0.0->-r requirements.txt (line 15)) (5.7.1)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.10.0->-r requirements.txt (line 10)) (3.13.5)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.23.0->sentence-transformers>=2.2.0->-r requirements.txt (line 1)) (1.4.3)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.23.0->sentence-transformers>=2.2.0->-r requirements.txt (line 1)) (0.28.1)
# Requirement already satisfied: typer in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.23.0->sentence-transformers>=2.2.0->-r requirements.txt (line 1)) (0.24.2)
# Collecting jedi>=0.16 (from ipython>=7.23.1->ipykernel>=6.0.0->-r requirements.txt (line 15))
#   Downloading jedi-0.20.0-py2.py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel>=6.0.0->-r requirements.txt (line 15)) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel>=6.0.0->-r requirements.txt (line 15)) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel>=6.0.0->-r requirements.txt (line 15)) (3.0.52)
# Requirement already satisfied: pygments in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel>=6.0.0->-r requirements.txt (line 15)) (2.20.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel>=6.0.0->-r requirements.txt (line 15)) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel>=6.0.0->-r requirements.txt (line 15)) (4.9.0)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.12/dist-packages (from jupyter-client>=6.1.12->ipykernel>=6.0.0->-r requirements.txt (line 15)) (0.4)
# Requirement already satisfied: jupyter-core>=4.9.2 in /usr/local/lib/python3.12/dist-packages (from jupyter-client>=6.1.12->ipykernel>=6.0.0->-r requirements.txt (line 15)) (5.9.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets>=2.10.0->-r requirements.txt (line 10)) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets>=2.10.0->-r requirements.txt (line 10)) (3.13)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets>=2.10.0->-r requirements.txt (line 10)) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets>=2.10.0->-r requirements.txt (line 10)) (2026.4.22)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.0.0->-r requirements.txt (line 3)) (1.3.0)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.12/dist-packages (from ipywidgets->jupyter>=1.0.0->-r requirements.txt (line 14)) (0.2.0)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.12/dist-packages (from ipywidgets->jupyter>=1.0.0->-r requirements.txt (line 14)) (3.6.10)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from ipywidgets->jupyter>=1.0.0->-r requirements.txt (line 14)) (3.0.16)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.0.0->-r requirements.txt (line 3)) (3.0.3)
# Collecting async-lru>=1.0.0 (from jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 14))
#   Downloading async_lru-2.3.0-py3-none-any.whl.metadata (7.6 kB)
# Collecting jupyter-lsp>=2.0.0 (from jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 14))
#   Downloading jupyter_lsp-2.3.1-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /usr/local/lib/python3.12/dist-packages (from jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 14)) (2.14.0)
# Collecting jupyterlab-server<3,>=2.28.0 (from jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 14))
#   Downloading jupyterlab_server-2.28.0-py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: notebook-shim>=0.2 in /usr/local/lib/python3.12/dist-packages (from jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 14)) (0.2.4)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (from nbconvert->jupyter>=1.0.0->-r requirements.txt (line 14)) (4.13.5)
# Requirement already satisfied: bleach!=5.0.0 in /usr/local/lib/python3.12/dist-packages (from bleach[css]!=5.0.0->nbconvert->jupyter>=1.0.0->-r requirements.txt (line 14)) (6.3.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.12/dist-packages (from nbconvert->jupyter>=1.0.0->-r requirements.txt (line 14)) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.12/dist-packages (from nbconvert->jupyter>=1.0.0->-r requirements.txt (line 14)) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /usr/local/lib/python3.12/dist-packages (from nbconvert->jupyter>=1.0.0->-r requirements.txt (line 14)) (3.2.0)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from nbconvert->jupyter>=1.0.0->-r requirements.txt (line 14)) (0.10.4)
# Requirement already satisfied: nbformat>=5.7 in /usr/local/lib/python3.12/dist-packages (from nbconvert->jupyter>=1.0.0->-r requirements.txt (line 14)) (5.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from nbconvert->jupyter>=1.0.0->-r requirements.txt (line 14)) (1.5.1)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.12/dist-packages (from notebook->jupyter>=1.0.0->-r requirements.txt (line 14)) (25.1.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.12/dist-packages (from notebook->jupyter>=1.0.0->-r requirements.txt (line 14)) (2.1.0)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.12/dist-packages (from notebook->jupyter>=1.0.0->-r requirements.txt (line 14)) (0.18.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.12/dist-packages (from notebook->jupyter>=1.0.0->-r requirements.txt (line 14)) (0.25.0)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.12/dist-packages (from notebook->jupyter>=1.0.0->-r requirements.txt (line 14)) (1.3.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.10.0->-r requirements.txt (line 10)) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.10.0->-r requirements.txt (line 10)) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.10.0->-r requirements.txt (line 10)) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.10.0->-r requirements.txt (line 10)) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.10.0->-r requirements.txt (line 10)) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.10.0->-r requirements.txt (line 10)) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.10.0->-r requirements.txt (line 10)) (1.23.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.12/dist-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert->jupyter>=1.0.0->-r requirements.txt (line 14)) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from bleach[css]!=5.0.0->nbconvert->jupyter>=1.0.0->-r requirements.txt (line 14)) (1.4.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.23.0->sentence-transformers>=2.2.0->-r requirements.txt (line 1)) (4.13.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.23.0->sentence-transformers>=2.2.0->-r requirements.txt (line 1)) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub>=0.23.0->sentence-transformers>=2.2.0->-r requirements.txt (line 1)) (0.16.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.6 in /usr/local/lib/python3.12/dist-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel>=6.0.0->-r requirements.txt (line 15)) (0.8.6)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.12/dist-packages (from jupyter-core>=4.9.2->jupyter-client>=6.1.12->ipykernel>=6.0.0->-r requirements.txt (line 15)) (4.9.6)
# Requirement already satisfied: jupyter-events>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 14)) (0.12.1)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 14)) (0.5.4)
# Requirement already satisfied: overrides>=5.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 14)) (7.7.0)
# Requirement already satisfied: websocket-client>=1.7 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 14)) (1.9.0)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.12/dist-packages (from argon2-cffi->notebook->jupyter>=1.0.0->-r requirements.txt (line 14)) (25.1.0)
# Requirement already satisfied: babel>=2.10 in /usr/local/lib/python3.12/dist-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 14)) (2.18.0)
# Collecting json5>=0.9.0 (from jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 14))
#   Downloading json5-0.14.0-py3-none-any.whl.metadata (36 kB)
# Requirement already satisfied: jsonschema>=4.18.0 in /usr/local/lib/python3.12/dist-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 14)) (4.26.0)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.12/dist-packages (from nbformat>=5.7->nbconvert->jupyter>=1.0.0->-r requirements.txt (line 14)) (2.21.2)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.12/dist-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel>=6.0.0->-r requirements.txt (line 15)) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=7.23.1->ipykernel>=6.0.0->-r requirements.txt (line 15)) (0.6.0)
# Requirement already satisfied: click>=8.2.1 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub>=0.23.0->sentence-transformers>=2.2.0->-r requirements.txt (line 1)) (8.3.3)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub>=0.23.0->sentence-transformers>=2.2.0->-r requirements.txt (line 1)) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub>=0.23.0->sentence-transformers>=2.2.0->-r requirements.txt (line 1)) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub>=0.23.0->sentence-transformers>=2.2.0->-r requirements.txt (line 1)) (0.0.4)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->nbconvert->jupyter>=1.0.0->-r requirements.txt (line 14)) (2.8.3)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 14)) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 14)) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 14)) (0.30.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 14)) (4.1.0)
# Requirement already satisfied: rfc3339-validator in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 14)) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 14)) (0.1.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface-hub>=0.23.0->sentence-transformers>=2.2.0->-r requirements.txt (line 1)) (4.0.0)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook->jupyter>=1.0.0->-r requirements.txt (line 14)) (2.0.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook->jupyter>=1.0.0->-r requirements.txt (line 14)) (3.0)
# Requirement already satisfied: fqdn in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 14)) (1.5.1)
# Requirement already satisfied: isoduration in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 14)) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 14)) (3.1.1)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 14)) (1.1.0)
# Requirement already satisfied: uri-template in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 14)) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 14)) (25.10.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->huggingface-hub>=0.23.0->sentence-transformers>=2.2.0->-r requirements.txt (line 1)) (0.1.2)
# Requirement already satisfied: lark>=1.2.2 in /usr/local/lib/python3.12/dist-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 14)) (1.3.1)
# Requirement already satisfied: arrow>=0.15.0 in /usr/local/lib/python3.12/dist-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 14)) (1.4.0)
# Downloading jupyter-1.1.1-py2.py3-none-any.whl (2.7 kB)
# Downloading jupyterlab-4.5.7-py3-none-any.whl (12.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.5/12.5 MB 115.5 MB/s eta 0:00:00
# Downloading async_lru-2.3.0-py3-none-any.whl (8.4 kB)
# Downloading jedi-0.20.0-py2.py3-none-any.whl (4.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 109.7 MB/s eta 0:00:00
# Downloading jupyter_lsp-2.3.1-py3-none-any.whl (77 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.5/77.5 kB 4.6 MB/s eta 0:00:00
# Downloading jupyterlab_server-2.28.0-py3-none-any.whl (59 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.8/59.8 kB 3.8 MB/s eta 0:00:00
# Downloading json5-0.14.0-py3-none-any.whl (36 kB)
# Building wheels for collected packages: langdetect
#   Building wheel for langdetect (setup.py) ... done
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993223 sha256=2cbc4310efaf335da96ec325e9413f9dd2caa2f6330d638b647e99828e3256f4
#   Stored in directory: /root/.cache/pip/wheels/c1/67/88/e844b5b022812e15a52e4eaa38a1e709e99f06f6639d7e3ba7
# Successfully built langdetect
# Installing collected packages: langdetect, json5, jedi, async-lru, jupyterlab-server, jupyter-lsp, jupyterlab, jupyter
# Successfully installed async-lru-2.3.0 jedi-0.20.0 json5-0.14.0 jupyter-1.1.1 jupyter-lsp-2.3.1 jupyterlab-4.5.7 jupyterlab-server-2.28.0 langdetect-1.0.9

# %%
import torch
print(torch.__version__)
print(torch.cuda.is_available())
# Out:
# 2.10.0+cpu
# False

# %%
# %cd src
# Out:
# /content/Cross-Lingual-Bengali-Idiom-Matching-Using-Multilingual-Sentence-Embeddings-Without-Translation/src

# %%
# !pwd
# Out:
# /content/Cross-Lingual-Bengali-Idiom-Matching-Using-Multilingual-Sentence-Embeddings-Without-Translation/src

# %%
# !python run_all.py
# Out:
# ============================================================
#   Bengali Cross-Lingual Idiom Matching — Full Pipeline
# ============================================================
#
# [DONE] Step 1: output exists → ../data/processed/bengali_merged.csv
# [DONE] Step 2: output exists → ../data/processed/triplets.csv
#
# ────────────────────────────────────────────────────────────
#   Running Step 3: 03_embedder.py
# ────────────────────────────────────────────────────────────
#
#
# ============================================================
#   STEP 3: Generating Embeddings  (mSBERT, LaBSE & BanglaBERT)
# ============================================================
#
# [✓] Idiom counts  →  Bengali: 8873  Hindi: 142  English: 14201
#
# [→] mSBERT embeddings already exist — delete folder to recompute.
#
# [→] LaBSE embeddings already exist — delete folder to recompute.
#
# [*] Loading BanglaBERT (csebuetnlp/banglabert)...
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json: 100% 586/586 [00:00<00:00, 2.25MB/s]
# pytorch_model.bin: 100% 443M/443M [00:03<00:00, 129MB/s]
# Loading weights: 100% 197/197 [00:00<00:00, 1453.50it/s, Materializing param=encoder.layer.11.output.dense.weight]
# ElectraModel LOAD REPORT from: csebuetnlp/banglabert
# Key                                               | Status     |  |
# --------------------------------------------------+------------+--+-
# discriminator_predictions.dense_prediction.bias   | UNEXPECTED |  |
# electra.embeddings.position_ids                   | UNEXPECTED |  |
# discriminator_predictions.dense_prediction.weight | UNEXPECTED |  |
# discriminator_predictions.dense.bias              | UNEXPECTED |  |
# discriminator_predictions.dense.weight            | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# model.safetensors:   0% 0.00/443M [00:00<?, ?B/s]
# tokenizer_config.json: 100% 119/119 [00:00<00:00, 510kB/s]
# model.safetensors:   0% 0.00/443M [00:01<?, ?B/s]
# vocab.txt: 528kB [00:00, 20.8MB/s]
# model.safetensors:   0% 0.00/443M [00:01<?, ?B/s]
# special_tokens_map.json: 100% 112/112 [00:00<00:00, 63.7kB/s]
# model.safetensors:   0% 0.00/443M [00:01<?, ?B/s][✓] BanglaBERT ready in 7.0s
#
# ── BanglaBERT: Bengali (8873) ──
#
# model.safetensors: 100% 443M/443M [00:05<00:00, 78.9MB/s]
#
# Batches:   1% 1/139 [00:06<15:35,  6.78s/it]
# Batches:   1% 2/139 [00:08<09:02,  3.96s/it]
# Batches:   2% 3/139 [00:10<06:40,  2.95s/it]
# Batches:   3% 4/139 [00:12<05:49,  2.59s/it]
# Batches:   4% 5/139 [00:14<05:15,  2.36s/it]
# Batches:   4% 6/139 [00:16<04:37,  2.08s/it]
# Batches:   5% 7/139 [00:17<04:06,  1.87s/it]
# Batches:   6% 8/139 [00:19<03:53,  1.78s/it]
# Batches:   6% 9/139 [00:20<03:39,  1.69s/it]
# Batches:   7% 10/139 [00:22<03:46,  1.76s/it]
# Batches:   8% 11/139 [00:23<03:32,  1.66s/it]
# Batches:   9% 12/139 [00:25<03:27,  1.63s/it]
# Batches:   9% 13/139 [00:27<03:22,  1.61s/it]
# Batches:  10% 14/139 [00:28<03:11,  1.53s/it]
# Batches:  11% 15/139 [00:29<03:00,  1.45s/it]
# Batches:  12% 16/139 [00:31<03:00,  1.47s/it]
# Batches:  12% 17/139 [00:32<02:57,  1.45s/it]
# Batches:  13% 18/139 [00:34<02:57,  1.47s/it]
# Batches:  14% 19/139 [00:35<02:55,  1.46s/it]
# Batches:  14% 20/139 [00:37<03:01,  1.53s/it]
# Batches:  15% 21/139 [00:40<03:49,  1.94s/it]
# Batches:  16% 22/139 [00:41<03:25,  1.76s/it]
# Batches:  17% 23/139 [00:42<03:09,  1.64s/it]
# Batches:  17% 24/139 [00:44<02:57,  1.54s/it]
# Batches:  18% 25/139 [00:45<02:49,  1.48s/it]
# Batches:  19% 26/139 [00:46<02:46,  1.47s/it]
# Batches:  19% 27/139 [00:48<02:32,  1.36s/it]
# Batches:  20% 28/139 [00:49<02:21,  1.27s/it]
# Batches:  21% 29/139 [00:50<02:27,  1.34s/it]
# Batches:  22% 30/139 [00:52<02:29,  1.37s/it]
# Batches:  22% 31/139 [00:53<02:25,  1.35s/it]
# Batches:  23% 32/139 [00:54<02:17,  1.29s/it]
# Batches:  24% 33/139 [00:55<02:14,  1.27s/it]
# Batches:  24% 34/139 [00:56<02:09,  1.23s/it]
# Batches:  25% 35/139 [00:57<02:04,  1.19s/it]
# Batches:  26% 36/139 [00:59<02:03,  1.20s/it]
# Batches:  27% 37/139 [01:00<02:04,  1.22s/it]
# Batches:  27% 38/139 [01:01<02:03,  1.22s/it]
# Batches:  28% 39/139 [01:02<02:04,  1.24s/it]
# Batches:  29% 40/139 [01:04<01:58,  1.20s/it]
# Batches:  29% 41/139 [01:05<01:54,  1.17s/it]
# Batches:  30% 42/139 [01:06<01:57,  1.21s/it]
# Batches:  31% 43/139 [01:07<01:56,  1.21s/it]
# Batches:  32% 44/139 [01:09<01:59,  1.26s/it]
# Batches:  32% 45/139 [01:10<01:56,  1.24s/it]
# Batches:  33% 46/139 [01:11<01:53,  1.22s/it]
# Batches:  34% 47/139 [01:12<01:51,  1.21s/it]
# Batches:  35% 48/139 [01:13<01:49,  1.20s/it]
# Batches:  35% 49/139 [01:15<02:00,  1.34s/it]
# Batches:  36% 50/139 [01:16<01:49,  1.23s/it]
# Batches:  37% 51/139 [01:17<01:48,  1.23s/it]
# Batches:  37% 52/139 [01:18<01:42,  1.18s/it]
# Batches:  38% 53/139 [01:19<01:37,  1.13s/it]
# Batches:  39% 54/139 [01:20<01:35,  1.13s/it]
# Batches:  40% 55/139 [01:21<01:31,  1.09s/it]
# Batches:  40% 56/139 [01:22<01:29,  1.08s/it]
# Batches:  41% 57/139 [01:24<01:31,  1.12s/it]
# Batches:  42% 58/139 [01:25<01:38,  1.22s/it]
# Batches:  42% 59/139 [01:26<01:41,  1.27s/it]
# Batches:  43% 60/139 [01:27<01:34,  1.20s/it]
# Batches:  44% 61/139 [01:29<01:30,  1.16s/it]
# Batches:  45% 62/139 [01:30<01:25,  1.11s/it]
# Batches:  45% 63/139 [01:31<01:22,  1.08s/it]
# Batches:  46% 64/139 [01:32<01:20,  1.08s/it]
# Batches:  47% 65/139 [01:33<01:19,  1.07s/it]
# Batches:  47% 66/139 [01:34<01:17,  1.06s/it]
# Batches:  48% 67/139 [01:35<01:14,  1.03s/it]
# Batches:  49% 68/139 [01:36<01:12,  1.02s/it]
# Batches:  50% 69/139 [01:37<01:17,  1.11s/it]
# Batches:  50% 70/139 [01:39<01:25,  1.24s/it]
# Batches:  51% 71/139 [01:40<01:20,  1.19s/it]
# Batches:  52% 72/139 [01:41<01:16,  1.14s/it]
# Batches:  53% 73/139 [01:42<01:13,  1.11s/it]
# Batches:  53% 74/139 [01:43<01:06,  1.03s/it]
# Batches:  54% 75/139 [01:44<01:07,  1.05s/it]
# Batches:  55% 76/139 [01:45<01:06,  1.05s/it]
# Batches:  55% 77/139 [01:46<01:05,  1.06s/it]
# Batches:  56% 78/139 [01:47<01:05,  1.08s/it]
# Batches:  57% 79/139 [01:48<01:03,  1.06s/it]
# Batches:  58% 80/139 [01:49<01:07,  1.14s/it]
# Batches:  58% 81/139 [01:51<01:09,  1.20s/it]
# Batches:  59% 82/139 [01:52<01:04,  1.13s/it]
# Batches:  60% 83/139 [01:53<01:02,  1.12s/it]
# Batches:  60% 84/139 [01:54<00:58,  1.05s/it]
# Batches:  61% 85/139 [01:55<00:56,  1.05s/it]
# Batches:  62% 86/139 [01:56<00:57,  1.09s/it]
# Batches:  63% 87/139 [01:57<00:56,  1.09s/it]
# Batches:  63% 88/139 [01:58<00:52,  1.04s/it]
# Batches:  64% 89/139 [01:59<00:49,  1.00it/s]
# Batches:  65% 90/139 [02:00<00:48,  1.01it/s]
# Batches:  65% 91/139 [02:01<00:46,  1.03it/s]
# Batches:  66% 92/139 [02:02<00:50,  1.07s/it]
# Batches:  67% 93/139 [02:03<00:48,  1.06s/it]
# Batches:  68% 94/139 [02:04<00:44,  1.01it/s]
# Batches:  68% 95/139 [02:05<00:45,  1.04s/it]
# Batches:  69% 96/139 [02:06<00:44,  1.04s/it]
# Batches:  70% 97/139 [02:07<00:41,  1.02it/s]
# Batches:  71% 98/139 [02:08<00:40,  1.01it/s]
# Batches:  71% 99/139 [02:09<00:42,  1.05s/it]
# Batches:  72% 100/139 [02:10<00:41,  1.05s/it]
# Batches:  73% 101/139 [02:11<00:37,  1.02it/s]
# Batches:  73% 102/139 [02:12<00:36,  1.00it/s]
# Batches:  74% 103/139 [02:13<00:39,  1.10s/it]
# Batches:  75% 104/139 [02:14<00:38,  1.09s/it]
# Batches:  76% 105/139 [02:15<00:36,  1.06s/it]
# Batches:  76% 106/139 [02:16<00:33,  1.01s/it]
# Batches:  77% 107/139 [02:17<00:31,  1.02it/s]
# Batches:  78% 108/139 [02:18<00:31,  1.00s/it]
# Batches:  78% 109/139 [02:19<00:29,  1.03it/s]
# Batches:  79% 110/139 [02:20<00:27,  1.04it/s]
# Batches:  80% 111/139 [02:21<00:26,  1.07it/s]
# Batches:  81% 112/139 [02:22<00:24,  1.10it/s]
# Batches:  81% 113/139 [02:23<00:24,  1.07it/s]
# Batches:  82% 114/139 [02:24<00:23,  1.06it/s]
# Batches:  83% 115/139 [02:25<00:23,  1.03it/s]
# Batches:  83% 116/139 [02:26<00:22,  1.01it/s]
# Batches:  84% 117/139 [02:27<00:20,  1.06it/s]
# Batches:  85% 118/139 [02:27<00:19,  1.10it/s]
# Batches:  86% 119/139 [02:28<00:17,  1.13it/s]
# Batches:  86% 120/139 [02:29<00:16,  1.15it/s]
# Batches:  87% 121/139 [02:30<00:16,  1.07it/s]
# Batches:  88% 122/139 [02:31<00:15,  1.12it/s]
# Batches:  88% 123/139 [02:32<00:14,  1.14it/s]
# Batches:  89% 124/139 [02:33<00:12,  1.18it/s]
# Batches:  90% 125/139 [02:33<00:11,  1.18it/s]
# Batches:  91% 126/139 [02:34<00:10,  1.19it/s]
# Batches:  91% 127/139 [02:35<00:10,  1.15it/s]
# Batches:  92% 128/139 [02:36<00:09,  1.17it/s]
# Batches:  93% 129/139 [02:37<00:08,  1.13it/s]
# Batches:  94% 130/139 [02:38<00:08,  1.10it/s]
# Batches:  94% 131/139 [02:39<00:06,  1.19it/s]
# Batches:  95% 132/139 [02:39<00:05,  1.25it/s]
# Batches:  96% 133/139 [02:40<00:04,  1.30it/s]
# Batches:  96% 134/139 [02:41<00:03,  1.34it/s]
# Batches:  97% 135/139 [02:42<00:03,  1.30it/s]
# Batches:  98% 136/139 [02:42<00:02,  1.27it/s]
# Batches:  99% 137/139 [02:43<00:01,  1.31it/s]
# Batches:  99% 138/139 [02:44<00:00,  1.29it/s]
# Batches: 100% 139/139 [02:44<00:00,  1.19s/it]
# ── BanglaBERT: Hindi & English skipped (monolingual) ──
# [✓] BanglaBERT embeddings saved → results/embeddings/BanglaBERT/
#     BanglaBERT[bn] shape: (8873, 768)
#
# [✓] All embeddings done.
# Next: python src/04_similarity.py
#
# [DONE] Step 4: output exists → ../results/similarity_scores.csv
# [DONE] Step 5: output exists → ../results/retrieval_metrics.csv
# [DONE] Step 6: output exists → ../results/clustering_metrics.csv
# [DONE] Step 7: output exists → ../results/full_evaluation_report.csv
# [DONE] Step 8: output exists → ../results/model_comparison_summary.txt
#
# ============================================================
#   ✅  PIPELINE COMPLETE
# ============================================================
#
# Key output files:
#   data/processed/triplets.csv              ← your dataset
#   results/similarity_scores.csv            ← Task 1 results
#   results/retrieval_metrics.csv            ← Task 2 results
#   results/clustering_metrics.csv           ← Task 3 results
#   results/full_evaluation_report.csv       ← all metrics
#   results/model_comparison_summary.txt     ← winner verdict
#   results/plots/final_comparison.png       ← comparison chart
